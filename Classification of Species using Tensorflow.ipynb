# %% [markdown]
# # Classification of Iris Plants using MLP
# ### Data Scientist: Paolo G. Hilado

# %% [markdown]
# Project Objective: Train a Multilayer Perceptron Machine learning model for Classification using Tensorflow package. Using the four features (sepal length, sepal width, petal length, and petal width), the model should classify the observation whether it is an iris setosa, iris virginica, or iris versicolor.

# %%
# Load the necessary libraries.
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import Input
from tensorflow.keras.models import load_model

# Load the Iris Data Set for the classification problem.
iris = load_iris()
data = iris.data #retrieving the features
target = iris.target #retrieving the response variable

# Create the DataFrame
df = pd.DataFrame(data, columns=iris.feature_names)
df['species'] = iris.target_names[target] # adding the response variable into the dataframe
df.head() # checking the first 6 rows
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
# Separating the Features and target variable.
X = df[iris.feature_names].values
y = df['species'].values

# Encode the target labels (species) as integers.
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Convert target labels to one-hot encoding.
# This is needed as the categorical_crossentropy loss function expects the target variable in 
# a one-hot coded format. This gets to represent categorical variables (in this case with 3 levels)
# to be in a binary format. For example, iris setosa being [1,0,0] etc. For multiclass classification
# it is also a best practice to use one-hot coding for Tensorflow.
y_onehot = to_categorical(y_encoded) 

# Do a data split with 70% train and 30% test set.
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.3, random_state=42)

# %%
# Build the Multi-Layer Perceptron Model.
model = tf.keras.Sequential([
    Input(shape=(X_train.shape[1],)),  # Explicitly define the input shape.
    tf.keras.layers.Dense(64, activation='relu'),  # Hidden layer
    tf.keras.layers.Dense(32, activation='relu'),  # Hidden layer
    tf.keras.layers.Dense(3, activation='softmax')  # Output layer
])

# Indicate the approaches for optimization, loss function, and evaluation of model performance.
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the MLP Model.
model.fit(X_train, y_train, epochs=50, batch_size=8, validation_data=(X_test, y_test))

# Evaluate model performance using accuracy as we have a balanced data set.
# Also check out the loss.
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test loss: {test_loss}")
print(f"Test accuracy: {test_acc * 100:.2f}%")
# Out:
# Epoch 1/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.3247 - loss: 1.3875 - val_accuracy: 0.3333 - val_loss: 1.0020
# Epoch 2/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4141 - loss: 0.9191 - val_accuracy: 0.7333 - val_loss: 0.8196
# Epoch 3/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6744 - loss: 0.8029 - val_accuracy: 0.7111 - val_loss: 0.7131
# Epoch 4/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7360 - loss: 0.7407 - val_accuracy: 0.8889 - val_loss: 0.6273
# Epoch 5/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7981 - loss: 0.6407 - val_accuracy: 0.7333 - val_loss: 0.5493
# Epoch 6/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6704 - loss: 0.6175 - val_accuracy: 0.8000 - val_loss: 0.5011
# Epoch 7/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7845 - loss: 0.5825 - val_accuracy: 0.8889 - val_loss: 0.4483
# Epoch 8/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8992 - loss: 0.5180 - val_accuracy: 0.8889 - val_loss: 0.4215
# Epoch 9/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9294 - loss: 0.4859 - val_accuracy: 0.9778 - val_loss: 0.3876
# Epoch 10/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8541 - loss: 0.4434 - val_accuracy: 0.8667 - val_loss: 0.3674
# Epoch 11/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8343 - loss: 0.4381 - val_accuracy: 0.9111 - val_loss: 0.3431
# Epoch 12/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9014 - loss: 0.3946 - val_accuracy: 1.0000 - val_loss: 0.3230
# Epoch 13/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9353 - loss: 0.4070 - val_accuracy: 0.9778 - val_loss: 0.3092
# Epoch 14/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9705 - loss: 0.3527 - val_accuracy: 0.9778 - val_loss: 0.2919
# Epoch 15/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9180 - loss: 0.3343 - val_accuracy: 0.9778 - val_loss: 0.2723
# Epoch 16/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9468 - loss: 0.3712 - val_accuracy: 0.9778 - val_loss: 0.2598
# Epoch 17/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9718 - loss: 0.3011 - val_accuracy: 0.9778 - val_loss: 0.2484
# Epoch 18/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9366 - loss: 0.3062 - val_accuracy: 1.0000 - val_loss: 0.2340
# Epoch 19/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9247 - loss: 0.3282 - val_accuracy: 1.0000 - val_loss: 0.2224
# Epoch 20/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9863 - loss: 0.2590 - val_accuracy: 0.9778 - val_loss: 0.2117
# Epoch 21/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9675 - loss: 0.2775 - val_accuracy: 1.0000 - val_loss: 0.2021
# Epoch 22/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9662 - loss: 0.2619 - val_accuracy: 0.9778 - val_loss: 0.1931
# Epoch 23/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9664 - loss: 0.2176 - val_accuracy: 0.9111 - val_loss: 0.1874
# Epoch 24/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9902 - loss: 0.2155 - val_accuracy: 0.9778 - val_loss: 0.1744
# Epoch 25/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9307 - loss: 0.2257 - val_accuracy: 1.0000 - val_loss: 0.1634
# Epoch 26/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9607 - loss: 0.2129 - val_accuracy: 1.0000 - val_loss: 0.1559
# Epoch 27/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9564 - loss: 0.2034 - val_accuracy: 0.9778 - val_loss: 0.1499
# Epoch 28/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9811 - loss: 0.1725 - val_accuracy: 0.9111 - val_loss: 0.1522
# Epoch 29/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9585 - loss: 0.2122 - val_accuracy: 0.9778 - val_loss: 0.1383
# Epoch 30/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9075 - loss: 0.2301 - val_accuracy: 0.9778 - val_loss: 0.1331
# Epoch 31/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9445 - loss: 0.2090 - val_accuracy: 0.9778 - val_loss: 0.1294
# Epoch 32/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9340 - loss: 0.1732 - val_accuracy: 1.0000 - val_loss: 0.1247
# Epoch 33/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9575 - loss: 0.1759 - val_accuracy: 0.9778 - val_loss: 0.1185
# Epoch 34/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9863 - loss: 0.1381 - val_accuracy: 0.9556 - val_loss: 0.1227
# Epoch 35/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9524 - loss: 0.1742 - val_accuracy: 0.9778 - val_loss: 0.1093
# Epoch 36/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9825 - loss: 0.1357 - val_accuracy: 0.9556 - val_loss: 0.1172
# Epoch 37/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9563 - loss: 0.1452 - val_accuracy: 0.9778 - val_loss: 0.1082
# Epoch 38/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9631 - loss: 0.1531 - val_accuracy: 1.0000 - val_loss: 0.1065
# Epoch 39/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9645 - loss: 0.1511 - val_accuracy: 0.9778 - val_loss: 0.0996
# Epoch 40/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9778 - loss: 0.1297 - val_accuracy: 0.9333 - val_loss: 0.1121
# Epoch 41/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9542 - loss: 0.1744 - val_accuracy: 1.0000 - val_loss: 0.0893
# Epoch 42/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9441 - loss: 0.1491 - val_accuracy: 1.0000 - val_loss: 0.0877
# Epoch 43/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9497 - loss: 0.1374 - val_accuracy: 1.0000 - val_loss: 0.0851
# Epoch 44/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9915 - loss: 0.1068 - val_accuracy: 1.0000 - val_loss: 0.0828
# Epoch 45/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9509 - loss: 0.1364 - val_accuracy: 1.0000 - val_loss: 0.0807
# Epoch 46/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9754 - loss: 0.1120 - val_accuracy: 1.0000 - val_loss: 0.0857
# Epoch 47/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9628 - loss: 0.1378 - val_accuracy: 1.0000 - val_loss: 0.0776
# Epoch 48/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9557 - loss: 0.1145 - val_accuracy: 1.0000 - val_loss: 0.0752
# Epoch 49/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9865 - loss: 0.1149 - val_accuracy: 0.9111 - val_loss: 0.1081
# Epoch 50/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9669 - loss: 0.1181 - val_accuracy: 0.9778 - val_loss: 0.0713
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9748 - loss: 0.0706
# Test loss: 0.05910559743642807
# Test accuracy: 97.78%

# %%
# Save the model for future use.
model.save('Iris_class.keras')  # This will save the model in a directory called 'Iris_class'

# %% [markdown]
# ### This project demonstrated the training of a Multi-Layer Perceptron ML model using Tensorflow library. The ML model has an accuracy of 97.78% for classifying the iris plant whether it is setosa, virginica, or versicolor.
