# %% [markdown]
# # <font face = 'Palatino Linotype' color = '#4297A0'> Classification of Iris Plants with MLP using Tensorflow <font/>
# ## <font face = 'Palatino Linotype' color = '#2F5061'> Data Scientists: Paolo Hilado <font/>

# %% [markdown]
# ## <font face = 'Palatino Linotype' color = '#4297A0'> Project Objective: <font/>
# <font face = 'Palatino Linotype' color = '#2F5061'> In this mini-project, we are going to train a Multilayer Perceptron Machine learning model using Tensorflow to classify the different species of iris plants. Using the four features (sepal length, sepal width, petal length, and petal width), the model should classify the observation whether it is an iris setosa, iris virginica, or iris versicolor. <font/>

# %%
# Load the necessary libraries.
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import Input
from tensorflow.keras.models import load_model

# Load the Iris Data Set for the classification problem.
iris = load_iris()
data = iris.data #retrieving the features
target = iris.target #retrieving the response variable

# Create the DataFrame
df = pd.DataFrame(data, columns=iris.feature_names)
df['species'] = iris.target_names[target] # adding the response variable into the dataframe
df.head() # checking the first 6 rows
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
# Separating the Features and target variable.
X = df[iris.feature_names].values
y = df['species'].values

# Encode the target labels (species) as integers.
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Convert target labels to one-hot encoding.
# This is needed as the categorical_crossentropy loss function expects the target variable in 
# a one-hot coded format. This gets to represent categorical variables (in this case with 3 levels)
# to be in a binary format. For example, iris setosa being [1,0,0] etc. For multiclass classification
# it is also a best practice to use one-hot coding for Tensorflow.
y_onehot = to_categorical(y_encoded) 

# Do a data split with 70% train and 30% test set.
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.3, random_state=42)

# %%
# Standardize all the continuous variables.
from sklearn.preprocessing import StandardScaler
# Initialize StandardScaler.
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Build the Multi-Layer Perceptron Model.
# Let us set up a simple deep neural network model given that we are working on
# a data set that has patterns that can easily be detected.
model = tf.keras.Sequential([
    Input(shape=(X_train.shape[1],)),  # Explicitly define the input shape.
    tf.keras.layers.Dense(16, activation='relu'),  # Hidden layer
    tf.keras.layers.Dense(12, activation='relu'),  
    tf.keras.layers.Dense(3, activation='softmax') # Output layer
])

# Indicate the approaches for optimization, loss function, and evaluation of model performance.
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the MLP Model.
model.fit(X_train, y_train, epochs=50, batch_size=8, validation_data=(X_test, y_test))

# Evaluate model performance using accuracy as we have a balanced data set.
# Also check out the loss.
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test loss: {test_loss}")
print(f"Test accuracy: {test_acc * 100:.2f}%")
# Out:
# Epoch 1/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.2972 - loss: 1.1816 - val_accuracy: 0.5333 - val_loss: 1.0195
# Epoch 2/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4939 - loss: 1.0430 - val_accuracy: 0.6667 - val_loss: 0.9028
# Epoch 3/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6053 - loss: 0.9556 - val_accuracy: 0.6667 - val_loss: 0.8121
# Epoch 4/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6442 - loss: 0.8851 - val_accuracy: 0.6889 - val_loss: 0.7517
# Epoch 5/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6906 - loss: 0.8193 - val_accuracy: 0.6889 - val_loss: 0.7047
# Epoch 6/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5899 - loss: 0.8277 - val_accuracy: 0.7111 - val_loss: 0.6623
# Epoch 7/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6038 - loss: 0.7875 - val_accuracy: 0.7111 - val_loss: 0.6264
# Epoch 8/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6598 - loss: 0.7185 - val_accuracy: 0.7111 - val_loss: 0.5956
# Epoch 9/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6110 - loss: 0.7066 - val_accuracy: 0.6889 - val_loss: 0.5682
# Epoch 10/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6116 - loss: 0.7155 - val_accuracy: 0.7111 - val_loss: 0.5426
# Epoch 11/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6359 - loss: 0.6504 - val_accuracy: 0.6667 - val_loss: 0.5195
# Epoch 12/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6943 - loss: 0.5716 - val_accuracy: 0.7333 - val_loss: 0.4978
# Epoch 13/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7536 - loss: 0.5324 - val_accuracy: 0.7556 - val_loss: 0.4763
# Epoch 14/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7430 - loss: 0.5706 - val_accuracy: 0.8000 - val_loss: 0.4562
# Epoch 15/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7852 - loss: 0.5692 - val_accuracy: 0.8222 - val_loss: 0.4385
# Epoch 16/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8198 - loss: 0.4750 - val_accuracy: 0.8222 - val_loss: 0.4233
# Epoch 17/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7920 - loss: 0.4896 - val_accuracy: 0.7778 - val_loss: 0.4097
# Epoch 18/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8462 - loss: 0.4436 - val_accuracy: 0.8222 - val_loss: 0.3972
# Epoch 19/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8441 - loss: 0.4132 - val_accuracy: 0.8222 - val_loss: 0.3855
# Epoch 20/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8330 - loss: 0.4210 - val_accuracy: 0.8444 - val_loss: 0.3751
# Epoch 21/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8807 - loss: 0.4030 - val_accuracy: 0.8889 - val_loss: 0.3660
# Epoch 22/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8885 - loss: 0.3760 - val_accuracy: 0.8667 - val_loss: 0.3584
# Epoch 23/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8616 - loss: 0.4184 - val_accuracy: 0.8889 - val_loss: 0.3518
# Epoch 24/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8607 - loss: 0.3613 - val_accuracy: 0.8889 - val_loss: 0.3463
# Epoch 25/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8553 - loss: 0.3500 - val_accuracy: 0.8889 - val_loss: 0.3395
# Epoch 26/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8853 - loss: 0.3533 - val_accuracy: 0.8889 - val_loss: 0.3336
# Epoch 27/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8850 - loss: 0.3104 - val_accuracy: 0.8889 - val_loss: 0.3266
# Epoch 28/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9140 - loss: 0.3020 - val_accuracy: 0.8889 - val_loss: 0.3227
# Epoch 29/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9267 - loss: 0.3038 - val_accuracy: 0.8889 - val_loss: 0.3177
# Epoch 30/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8659 - loss: 0.2965 - val_accuracy: 0.8889 - val_loss: 0.3059
# Epoch 31/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9090 - loss: 0.2938 - val_accuracy: 0.8889 - val_loss: 0.2953
# Epoch 32/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9236 - loss: 0.2785 - val_accuracy: 0.8889 - val_loss: 0.2852
# Epoch 33/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9301 - loss: 0.2559 - val_accuracy: 0.8889 - val_loss: 0.2807
# Epoch 34/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8926 - loss: 0.3055 - val_accuracy: 0.8889 - val_loss: 0.2671
# Epoch 35/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9171 - loss: 0.2530 - val_accuracy: 0.8889 - val_loss: 0.2576
# Epoch 36/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9521 - loss: 0.2160 - val_accuracy: 0.9111 - val_loss: 0.2490
# Epoch 37/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9300 - loss: 0.2297 - val_accuracy: 0.9111 - val_loss: 0.2354
# Epoch 38/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9443 - loss: 0.2196 - val_accuracy: 0.9111 - val_loss: 0.2309
# Epoch 39/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9070 - loss: 0.2179 - val_accuracy: 0.9111 - val_loss: 0.2256
# Epoch 40/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9203 - loss: 0.2118 - val_accuracy: 0.9111 - val_loss: 0.2123
# Epoch 41/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8938 - loss: 0.2143 - val_accuracy: 0.9333 - val_loss: 0.1992
# Epoch 42/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9458 - loss: 0.2010 - val_accuracy: 0.9333 - val_loss: 0.1944
# Epoch 43/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9431 - loss: 0.1992 - val_accuracy: 0.9333 - val_loss: 0.1885
# Epoch 44/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8838 - loss: 0.2715 - val_accuracy: 0.9556 - val_loss: 0.1807
# Epoch 45/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9207 - loss: 0.2067 - val_accuracy: 0.9556 - val_loss: 0.1795
# Epoch 46/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8843 - loss: 0.2413 - val_accuracy: 0.9556 - val_loss: 0.1750
# Epoch 47/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9259 - loss: 0.1997 - val_accuracy: 0.9556 - val_loss: 0.1698
# Epoch 48/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9384 - loss: 0.1817 - val_accuracy: 0.9556 - val_loss: 0.1581
# Epoch 49/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9569 - loss: 0.1431 - val_accuracy: 0.9556 - val_loss: 0.1519
# Epoch 50/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9595 - loss: 0.1386 - val_accuracy: 0.9556 - val_loss: 0.1489
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9600 - loss: 0.1418
# Test loss: 0.15949955582618713
# Test accuracy: 95.56%

# %%
# Save the model for future use.
model.save('MLP_TF_ClassIris.keras')  # This will save the model in a directory called 'Iris_class'

# %% [markdown]
# ## <font face = 'Palatino Linotype' color = '#4297A0'> Summary:<font/>
# <font face = 'Palatino Linotype' color = '#2F5061'> This mini-project demonstrated the training of a Multi-Layer Perceptron ML model using Tensorflow library. The ML model has an accuracy of 95.56% for classifying the iris plant whether it is setosa, virginica, or versicolor. A simple deep neural network setup was considered given that the data set is less complex and that we also ensure that it avoids overfitting. <font/>
